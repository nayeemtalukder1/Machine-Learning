# %%
import pandas as pd
df = pd.read_csv("carprices.csv")
df
# Out:
#                 Car Model  Mileage  Sell Price($)  Age(yrs)
# 0                  BMW X5    69000          18000         6
# 1                  BMW X5    35000          34000         3
# 2                  BMW X5    57000          26100         5
# 3                  BMW X5    22500          40000         2
# 4                  BMW X5    46000          31500         4
# 5                 Audi A5    59000          29400         5
# 6                 Audi A5    52000          32000         5
# 7                 Audi A5    72000          19300         6
# 8                 Audi A5    91000          12000         8
# 9   Mercedez Benz C class    67000          22000         6
# 10  Mercedez Benz C class    83000          20000         7
# 11  Mercedez Benz C class    79000          21000         7
# 12  Mercedez Benz C class    59000          33000         5

# %%
dummies = pd.get_dummies(df["Car Model"])
dummies
# Out:
#     Audi A5  BMW X5  Mercedez Benz C class
# 0     False    True                  False
# 1     False    True                  False
# 2     False    True                  False
# 3     False    True                  False
# 4     False    True                  False
# 5      True   False                  False
# 6      True   False                  False
# 7      True   False                  False
# 8      True   False                  False
# 9     False   False                   True
# 10    False   False                   True
# 11    False   False                   True
# 12    False   False                   True

# %%
merged = pd.concat([df,dummies], axis='columns')
merged
# Out:
#                 Car Model  Mileage  Sell Price($)  Age(yrs)  Audi A5  BMW X5  \
# 0                  BMW X5    69000          18000         6    False    True
# 1                  BMW X5    35000          34000         3    False    True
# 2                  BMW X5    57000          26100         5    False    True
# 3                  BMW X5    22500          40000         2    False    True
# 4                  BMW X5    46000          31500         4    False    True
# 5                 Audi A5    59000          29400         5     True   False
# 6                 Audi A5    52000          32000         5     True   False
# 7                 Audi A5    72000          19300         6     True   False
# 8                 Audi A5    91000          12000         8     True   False
# 9   Mercedez Benz C class    67000          22000         6    False   False
# 10  Mercedez Benz C class    83000          20000         7    False   False
# 11  Mercedez Benz C class    79000          21000         7    False   False
# 12  Mercedez Benz C class    59000          33000         5    False   False
#
#     Mercedez Benz C class
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# 5                   False
# 6                   False
# 7                   False
# 8                   False
# 9                    True
# 10                   True
# 11                   True
# 12                   True

# %%
final = merged.drop(['Car Model','Mercedez Benz C class'], axis='columns')
final
# Out:
#     Mileage  Sell Price($)  Age(yrs)  Audi A5  BMW X5
# 0     69000          18000         6    False    True
# 1     35000          34000         3    False    True
# 2     57000          26100         5    False    True
# 3     22500          40000         2    False    True
# 4     46000          31500         4    False    True
# 5     59000          29400         5     True   False
# 6     52000          32000         5     True   False
# 7     72000          19300         6     True   False
# 8     91000          12000         8     True   False
# 9     67000          22000         6    False   False
# 10    83000          20000         7    False   False
# 11    79000          21000         7    False   False
# 12    59000          33000         5    False   False

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
X = final.drop('Sell Price($)', axis='columns')
X
# Out:
#     Mileage  Age(yrs)  Audi A5  BMW X5
# 0     69000         6    False    True
# 1     35000         3    False    True
# 2     57000         5    False    True
# 3     22500         2    False    True
# 4     46000         4    False    True
# 5     59000         5     True   False
# 6     52000         5     True   False
# 7     72000         6     True   False
# 8     91000         8     True   False
# 9     67000         6    False   False
# 10    83000         7    False   False
# 11    79000         7    False   False
# 12    59000         5    False   False

# %%
y = final['Sell Price($)']
y
# Out:
# 0     18000
# 1     34000
# 2     26100
# 3     40000
# 4     31500
# 5     29400
# 6     32000
# 7     19300
# 8     12000
# 9     22000
# 10    20000
# 11    21000
# 12    33000
# Name: Sell Price($), dtype: int64

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.predict([[3500,3,False,True]])
# Out:
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([46945.63042968])

# %%
model.score(X,y)
# Out:
# 0.9417050937281082

# %% [markdown]
# One Hot Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
dfle = df
dfle['Car Model'] = le.fit_transform(dfle['Car Model'])

# %%
dfle
# Out:
#     Car Model  Mileage  Sell Price($)  Age(yrs)
# 0           1    69000          18000         6
# 1           1    35000          34000         3
# 2           1    57000          26100         5
# 3           1    22500          40000         2
# 4           1    46000          31500         4
# 5           0    59000          29400         5
# 6           0    52000          32000         5
# 7           0    72000          19300         6
# 8           0    91000          12000         8
# 9           2    67000          22000         6
# 10          2    83000          20000         7
# 11          2    79000          21000         7
# 12          2    59000          33000         5

# %%
X = dfle[['Car Model','Mileage']].values
X
# Out:
# array([[    1, 69000],
#        [    1, 35000],
#        [    1, 57000],
#        [    1, 22500],
#        [    1, 46000],
#        [    0, 59000],
#        [    0, 52000],
#        [    0, 72000],
#        [    0, 91000],
#        [    2, 67000],
#        [    2, 83000],
#        [    2, 79000],
#        [    2, 59000]], dtype=int64)

# %%
y = dfle['Sell Price($)']
y
# Out:
# 0     18000
# 1     34000
# 2     26100
# 3     40000
# 4     31500
# 5     29400
# 6     32000
# 7     19300
# 8     12000
# 9     22000
# 10    20000
# 11    21000
# 12    33000
# Name: Sell Price($), dtype: int64

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

column_transformer = ColumnTransformer(
    transformers=[
        ('ohe', OneHotEncoder(), [0])  # Apply OneHotEncoder to the first column
    ],
    remainder='passthrough'  # Keep other columns unchanged
)

# Fit and transform the data
X = column_transformer.fit_transform(X)

print(X)
# Out:
# [[1.00e+00 0.00e+00 1.00e+00 0.00e+00 6.90e+04]
#  [1.00e+00 0.00e+00 1.00e+00 0.00e+00 3.50e+04]
#  [1.00e+00 0.00e+00 1.00e+00 0.00e+00 5.70e+04]
#  [1.00e+00 0.00e+00 1.00e+00 0.00e+00 2.25e+04]
#  [1.00e+00 0.00e+00 1.00e+00 0.00e+00 4.60e+04]
#  [0.00e+00 1.00e+00 0.00e+00 0.00e+00 5.90e+04]
#  [0.00e+00 1.00e+00 0.00e+00 0.00e+00 5.20e+04]
#  [0.00e+00 1.00e+00 0.00e+00 0.00e+00 7.20e+04]
#  [0.00e+00 1.00e+00 0.00e+00 0.00e+00 9.10e+04]
#  [1.00e+00 0.00e+00 0.00e+00 1.00e+00 6.70e+04]
#  [1.00e+00 0.00e+00 0.00e+00 1.00e+00 8.30e+04]
#  [1.00e+00 0.00e+00 0.00e+00 1.00e+00 7.90e+04]
#  [1.00e+00 0.00e+00 0.00e+00 1.00e+00 5.90e+04]]

# %%
X = X[:,1:]
X
# Out:
# array([[1.00e+00, 0.00e+00, 6.90e+04],
#        [1.00e+00, 0.00e+00, 3.50e+04],
#        [1.00e+00, 0.00e+00, 5.70e+04],
#        [1.00e+00, 0.00e+00, 2.25e+04],
#        [1.00e+00, 0.00e+00, 4.60e+04],
#        [0.00e+00, 0.00e+00, 5.90e+04],
#        [0.00e+00, 0.00e+00, 5.20e+04],
#        [0.00e+00, 0.00e+00, 7.20e+04],
#        [0.00e+00, 0.00e+00, 9.10e+04],
#        [0.00e+00, 1.00e+00, 6.70e+04],
#        [0.00e+00, 1.00e+00, 8.30e+04],
#        [0.00e+00, 1.00e+00, 7.90e+04],
#        [0.00e+00, 1.00e+00, 5.90e+04]])

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.predict([1,69000,6])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 model.predict([1,69000,6])
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_base.py:306, in LinearModel.predict(self, X)
#     292 def predict(self, X):
#     293     """
#     294     Predict using the linear model.
#     295
#    (...)
#     304         Returns predicted values.
#     305     """
# --> 306     return self._decision_function(X)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_base.py:285, in LinearModel._decision_function(self, X)
#     282 def _decision_function(self, X):
#     283     check_is_fitted(self)
# --> 285     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     286     coef_ = self.coef_
#     287     if coef_.ndim == 1:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:633, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     631         out = X, y
#     632 elif not no_val_X and no_val_y:
# --> 633     out = check_array(X, input_name="X", **check_params)
#     634 elif no_val_X and not no_val_y:
#     635     out = _check_y(y, **check_params)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1045, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1038         else:
#    1039             msg = (
#    1040                 f"Expected 2D array, got 1D array instead:\narray={array}.\n"
#    1041                 "Reshape your data either using array.reshape(-1, 1) if "
#    1042                 "your data has a single feature or array.reshape(1, -1) "
#    1043                 "if it contains a single sample."
#    1044             )
# -> 1045         raise ValueError(msg)
#    1047 if dtype_numeric and hasattr(array.dtype, "kind") and array.dtype.kind in "USV":
#    1048     raise ValueError(
#    1049         "dtype='numeric' is not compatible with arrays of bytes/strings."
#    1050         "Convert your data to numeric values explicitly instead."
#    1051     )
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[    1 69000     6].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
